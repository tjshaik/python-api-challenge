# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %% [markdown]
# My discusion at the end of each section as shown in the starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"+ "appid=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=434f6df2e59d396ad9b46ba9a488811d'

# %%
city_url = f"{url}&q={city}"
city_url
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -159.775, 'lat': -21.2078},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 298.18,
#   'feels_like': 299.04,
#   'temp_min': 298.18,
#   'temp_max': 298.18,
#   'pressure': 1012,
#   'humidity': 88},
#  'visibility': 10000,
#  'wind': {'speed': 6.17, 'deg': 50},
#  'clouds': {'all': 40},
#  'dt': 1686629192,
#  'sys': {'type': 1,
#   'id': 7271,
#   'country': 'CK',
#   'sunrise': 1686590001,
#   'sunset': 1686629085},
#  'timezone': -36000,
#  'id': 4035715,
#  'name': 'Avarua',
#  'cod': 200}

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"+ "appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = url +"&qi"+ urllib.request.pathname2url[city]
    city_url = f"{url}&q={city}&units=metric"
#Response = requests.get(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    #print(f"Processing Record {record_count} of Set {set_count}|{city}")      

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lon": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | chernyshevskiy
# Processing Record 7 of Set 1 | pangoa
# Processing Record 8 of Set 1 | pisco
# Processing Record 9 of Set 1 | ta`u
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | luckeesarai
# Processing Record 13 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 1 | minas de marcona
# Processing Record 15 of Set 1 | port maria
# Processing Record 16 of Set 1 | hawaiian paradise park
# Processing Record 17 of Set 1 | christchurch
# Processing Record 18 of Set 1 | klyuchi
# Processing Record 19 of Set 1 | st. john's
# Processing Record 20 of Set 1 | pelabuhanratu
# Processing Record 21 of Set 1 | lazaro cardenas
# Processing Record 22 of Set 1 | papatowai
# Processing Record 23 of Set 1 | adamstown
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | wailua homesteads
# Processing Record 26 of Set 1 | ancud
# Processing Record 27 of Set 1 | blackmans bay
# Processing Record 28 of Set 1 | hakui
# Processing Record 29 of Set 1 | hadibu
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | lihue
# Processing Record 32 of Set 1 | san patricio
# Processing Record 33 of Set 1 | yuzhno-kurilsk
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | aasiaat
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | kulhudhuffushi
# Processing Record 39 of Set 1 | arteche
# Processing Record 40 of Set 1 | port saint john's
# Processing Record 41 of Set 1 | vorgashor
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | tingo maria
# Processing Record 44 of Set 1 | swift current
# Processing Record 45 of Set 1 | port mathurin
# Processing Record 46 of Set 1 | sitka
# Processing Record 47 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 48 of Set 1 | tulun
# Processing Record 49 of Set 1 | liwale
# Processing Record 50 of Set 1 | newman
# Processing Record 0 of Set 2 | senatobia
# Processing Record 1 of Set 2 | kingston
# Processing Record 2 of Set 2 | malango
# Processing Record 3 of Set 2 | stanley
# Processing Record 4 of Set 2 | tsiombe
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | enewetak
# Processing Record 8 of Set 2 | aykhal
# Processing Record 9 of Set 2 | richards bay
# Processing Record 10 of Set 2 | chaiya
# Processing Record 11 of Set 2 | mgandu
# Processing Record 12 of Set 2 | greymouth
# Processing Record 13 of Set 2 | ambilobe
# Processing Record 14 of Set 2 | puerto natales
# Processing Record 15 of Set 2 | kapuskasing
# Processing Record 16 of Set 2 | sao jose da coroa grande
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | nha trang
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | cachoeira do sul
# Processing Record 21 of Set 2 | invercargill
# Processing Record 22 of Set 2 | tucuma
# Processing Record 23 of Set 2 | atafu village
# Processing Record 24 of Set 2 | badger
# Processing Record 25 of Set 2 | college
# Processing Record 26 of Set 2 | ocean pointe
# City not found. Skipping...
# Processing Record 27 of Set 2 | ushuaia
# Processing Record 28 of Set 2 | luderitz
# Processing Record 29 of Set 2 | whitehorse
# Processing Record 30 of Set 2 | nombre de dios
# Processing Record 31 of Set 2 | rio branco
# Processing Record 32 of Set 2 | happy valley-goose bay
# Processing Record 33 of Set 2 | acarau
# Processing Record 34 of Set 2 | san antonio de pale
# Processing Record 35 of Set 2 | roma
# Processing Record 36 of Set 2 | remire-montjoly
# Processing Record 37 of Set 2 | bay harbor
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | chonchi
# Processing Record 40 of Set 2 | nelson bay
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | oranjemund
# Processing Record 43 of Set 2 | luwingu
# Processing Record 44 of Set 2 | likasi
# Processing Record 45 of Set 2 | cinisi
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | kapa'a
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | kenora
# Processing Record 0 of Set 3 | vilyuchinsk
# Processing Record 1 of Set 3 | manokwari
# Processing Record 2 of Set 3 | dalyellup
# Processing Record 3 of Set 3 | ouro preto do oeste
# Processing Record 4 of Set 3 | vlore
# Processing Record 5 of Set 3 | san pedro pochutla
# Processing Record 6 of Set 3 | kirakira
# Processing Record 7 of Set 3 | isafjordur
# Processing Record 8 of Set 3 | margaret river
# Processing Record 9 of Set 3 | hamilton
# Processing Record 10 of Set 3 | serhiyivka
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | birao
# Processing Record 13 of Set 3 | itambacuri
# Processing Record 14 of Set 3 | ryotsu-minato
# Processing Record 15 of Set 3 | las veredas
# Processing Record 16 of Set 3 | saint-francois
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | melfort
# Processing Record 19 of Set 3 | tutoia
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | saipan
# Processing Record 22 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 23 of Set 3 | naze
# Processing Record 24 of Set 3 | aguas vermelhas
# Processing Record 25 of Set 3 | kerikeri
# Processing Record 26 of Set 3 | waitangi
# Processing Record 27 of Set 3 | gadzhiyevo
# Processing Record 28 of Set 3 | turkmenbasy
# Processing Record 29 of Set 3 | puerto ayora
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | beau vallon
# Processing Record 32 of Set 3 | kuna
# Processing Record 33 of Set 3 | bambanglipuro
# Processing Record 34 of Set 3 | ola
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | linda
# Processing Record 38 of Set 3 | roswell
# Processing Record 39 of Set 3 | hilo
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | piacabucu
# Processing Record 42 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 43 of Set 3 | as sulayyil
# Processing Record 44 of Set 3 | dabeiba
# Processing Record 45 of Set 3 | namibe
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | sweet home
# Processing Record 48 of Set 3 | brigantine
# Processing Record 49 of Set 3 | antalaha
# Processing Record 0 of Set 4 | lodeynoye pole
# Processing Record 1 of Set 4 | celestun
# Processing Record 2 of Set 4 | valle de la pascua
# Processing Record 3 of Set 4 | marau
# Processing Record 4 of Set 4 | nurmes
# Processing Record 5 of Set 4 | afaahiti
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | dabou
# Processing Record 8 of Set 4 | al harithah
# Processing Record 9 of Set 4 | ar rudayyif
# Processing Record 10 of Set 4 | olyokminsk
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | itoman
# Processing Record 13 of Set 4 | tazovsky
# Processing Record 14 of Set 4 | bayevo
# Processing Record 15 of Set 4 | haiku-pauwela
# Processing Record 16 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 4 | maracas
# Processing Record 18 of Set 4 | keshorai patan
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | ust-nera
# Processing Record 21 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 4 | al ghayzah
# Processing Record 23 of Set 4 | keflavik
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | saurimo
# Processing Record 26 of Set 4 | zhezqazghan
# Processing Record 27 of Set 4 | ain taya
# Processing Record 28 of Set 4 | ducheng
# Processing Record 29 of Set 4 | aldinga beach
# Processing Record 30 of Set 4 | porto novo
# Processing Record 31 of Set 4 | rio grande
# Processing Record 32 of Set 4 | nova vicosa
# Processing Record 33 of Set 4 | walvis bay
# Processing Record 34 of Set 4 | saguenay
# Processing Record 35 of Set 4 | northam
# Processing Record 36 of Set 4 | pangai
# Processing Record 37 of Set 4 | fale old settlement
# Processing Record 38 of Set 4 | ataq
# Processing Record 39 of Set 4 | gamboma
# Processing Record 40 of Set 4 | pyapon
# Processing Record 41 of Set 4 | lemvig
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | marsh harbour
# Processing Record 44 of Set 4 | noumea
# Processing Record 45 of Set 4 | el obeid
# Processing Record 46 of Set 4 | ugbokpo
# Processing Record 47 of Set 4 | idri
# Processing Record 48 of Set 4 | olonkinbyen
# Processing Record 49 of Set 4 | urucara
# Processing Record 0 of Set 5 | kaa-khem
# Processing Record 1 of Set 5 | severo-yeniseyskiy
# Processing Record 2 of Set 5 | nagqu
# Processing Record 3 of Set 5 | ringkobing
# Processing Record 4 of Set 5 | usogorsk
# Processing Record 5 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 5 | labrador city
# Processing Record 7 of Set 5 | canutama
# Processing Record 8 of Set 5 | mrkonjic grad
# Processing Record 9 of Set 5 | port blair
# Processing Record 10 of Set 5 | usinsk
# Processing Record 11 of Set 5 | la passe
# Processing Record 12 of Set 5 | kangding
# Processing Record 13 of Set 5 | uturoa
# Processing Record 14 of Set 5 | arraial do cabo
# Processing Record 15 of Set 5 | ruteng
# Processing Record 16 of Set 5 | media luna
# Processing Record 17 of Set 5 | belmonte
# Processing Record 18 of Set 5 | puerto baquerizo moreno
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | verkhnevilyuysk
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | fortaleza
# Processing Record 23 of Set 5 | cabedelo
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | sala
# Processing Record 26 of Set 5 | banlung
# Processing Record 27 of Set 5 | bubaque
# Processing Record 28 of Set 5 | maracaibo
# Processing Record 29 of Set 5 | thomaston
# Processing Record 30 of Set 5 | leh
# Processing Record 31 of Set 5 | carlos chagas
# Processing Record 32 of Set 5 | kalmunai
# Processing Record 33 of Set 5 | boguchany
# Processing Record 34 of Set 5 | yanchep
# Processing Record 35 of Set 5 | bamboo flat
# Processing Record 36 of Set 5 | sept-iles
# Processing Record 37 of Set 5 | miyanoura
# City not found. Skipping...
# Processing Record 38 of Set 5 | rawson
# Processing Record 39 of Set 5 | polyarnyy
# Processing Record 40 of Set 5 | samarinda
# Processing Record 41 of Set 5 | muan
# Processing Record 42 of Set 5 | sungai penuh
# Processing Record 43 of Set 5 | balikpapan
# Processing Record 44 of Set 5 | sierra grande
# Processing Record 45 of Set 5 | papao
# Processing Record 46 of Set 5 | pariaman
# Processing Record 47 of Set 5 | kourou
# Processing Record 48 of Set 5 | taro
# Processing Record 49 of Set 5 | selfoss
# Processing Record 0 of Set 6 | rongelap
# Processing Record 1 of Set 6 | summerside
# Processing Record 2 of Set 6 | pendembu
# Processing Record 3 of Set 6 | pontianak
# Processing Record 4 of Set 6 | san pedro
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | brisas de zicatela
# Processing Record 7 of Set 6 | bandar lampung
# Processing Record 8 of Set 6 | ghat
# Processing Record 9 of Set 6 | nar'yan-mar
# Processing Record 10 of Set 6 | calama
# Processing Record 11 of Set 6 | kolyvan'
# Processing Record 12 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 6 | punta arenas
# Processing Record 14 of Set 6 | buala
# Processing Record 15 of Set 6 | dryden
# Processing Record 16 of Set 6 | at taj
# Processing Record 17 of Set 6 | traralgon
# Processing Record 18 of Set 6 | sakaiminato
# Processing Record 19 of Set 6 | olinda
# Processing Record 20 of Set 6 | pemba
# Processing Record 21 of Set 6 | touros
# Processing Record 22 of Set 6 | pandan
# Processing Record 23 of Set 6 | nova sintra
# Processing Record 24 of Set 6 | kone
# Processing Record 25 of Set 6 | machico
# Processing Record 26 of Set 6 | fada
# Processing Record 27 of Set 6 | howrah
# Processing Record 28 of Set 6 | thames
# Processing Record 29 of Set 6 | yishui
# Processing Record 30 of Set 6 | antsiranana
# Processing Record 31 of Set 6 | barah
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | fisterra
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | purwodadi
# Processing Record 37 of Set 6 | morehead city
# Processing Record 38 of Set 6 | bilibino
# Processing Record 39 of Set 6 | veraval
# Processing Record 40 of Set 6 | marka
# Processing Record 41 of Set 6 | ardestan
# Processing Record 42 of Set 6 | bayganin
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | changling
# Processing Record 45 of Set 6 | freetown
# Processing Record 46 of Set 6 | vryburg
# Processing Record 47 of Set 6 | argo
# Processing Record 48 of Set 6 | pointe-noire
# Processing Record 49 of Set 6 | sassandra
# Processing Record 0 of Set 7 | odda
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | sao vicente
# Processing Record 3 of Set 7 | flying fish cove
# Processing Record 4 of Set 7 | gunjur
# Processing Record 5 of Set 7 | redencao
# Processing Record 6 of Set 7 | huilong
# Processing Record 7 of Set 7 | tual
# Processing Record 8 of Set 7 | garachico
# Processing Record 9 of Set 7 | mahibadhoo
# Processing Record 10 of Set 7 | port augusta
# Processing Record 11 of Set 7 | vladimirskaya
# Processing Record 12 of Set 7 | mhamid
# Processing Record 13 of Set 7 | juli
# Processing Record 14 of Set 7 | nizhny tagil
# Processing Record 15 of Set 7 | fort st. john
# Processing Record 16 of Set 7 | san luis
# Processing Record 17 of Set 7 | amahai
# Processing Record 18 of Set 7 | son la
# Processing Record 19 of Set 7 | zheleznogorsk-ilimskiy
# Processing Record 20 of Set 7 | jining
# Processing Record 21 of Set 7 | yaren
# Processing Record 22 of Set 7 | gaogou
# Processing Record 23 of Set 7 | gorontalo
# Processing Record 24 of Set 7 | bardai
# Processing Record 25 of Set 7 | oriximina
# Processing Record 26 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 27 of Set 7 | claveria
# Processing Record 28 of Set 7 | inebolu
# Processing Record 29 of Set 7 | le port
# Processing Record 30 of Set 7 | port douglas
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | fort bragg
# Processing Record 33 of Set 7 | avarua
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | jian'ou
# Processing Record 36 of Set 7 | layou
# Processing Record 37 of Set 7 | longyearbyen
# Processing Record 38 of Set 7 | lompoc
# Processing Record 39 of Set 7 | ceeldheer
# Processing Record 40 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 7 | booue
# Processing Record 42 of Set 7 | znamenskoye
# Processing Record 43 of Set 7 | illizi
# Processing Record 44 of Set 7 | yeppoon
# Processing Record 45 of Set 7 | abepura
# Processing Record 46 of Set 7 | twin falls
# Processing Record 47 of Set 7 | castillos
# Processing Record 48 of Set 7 | lebu
# Processing Record 49 of Set 7 | belyy yar
# Processing Record 0 of Set 8 | argos orestiko
# Processing Record 1 of Set 8 | el fasher
# Processing Record 2 of Set 8 | chibuto
# Processing Record 3 of Set 8 | kiruna
# Processing Record 4 of Set 8 | goaso
# City not found. Skipping...
# Processing Record 5 of Set 8 | shixing
# Processing Record 6 of Set 8 | gizo
# Processing Record 7 of Set 8 | weno
# Processing Record 8 of Set 8 | sittwe
# Processing Record 9 of Set 8 | kasongo-lunda
# Processing Record 10 of Set 8 | plettenberg bay
# Processing Record 11 of Set 8 | whakatane
# Processing Record 12 of Set 8 | westport
# Processing Record 13 of Set 8 | susuman
# Processing Record 14 of Set 8 | baruun-urt
# Processing Record 15 of Set 8 | whyalla stuart
# City not found. Skipping...
# Processing Record 16 of Set 8 | biltine
# Processing Record 17 of Set 8 | quellon
# Processing Record 18 of Set 8 | ambodifotatra
# Processing Record 19 of Set 8 | verdal
# Processing Record 20 of Set 8 | shevchenko
# Processing Record 21 of Set 8 | anuradhapura
# Processing Record 22 of Set 8 | knyaze-volkonskoye
# Processing Record 23 of Set 8 | chibougamau
# Processing Record 24 of Set 8 | katsuren-haebaru
# Processing Record 25 of Set 8 | mount pleasant
# Processing Record 26 of Set 8 | longonjo
# Processing Record 27 of Set 8 | olgii
# City not found. Skipping...
# Processing Record 28 of Set 8 | caleta de carquin
# Processing Record 29 of Set 8 | paramonga
# Processing Record 30 of Set 8 | aripuana
# Processing Record 31 of Set 8 | sinan
# Processing Record 32 of Set 8 | ishigaki
# Processing Record 33 of Set 8 | crane
# Processing Record 34 of Set 8 | vuktyl
# Processing Record 35 of Set 8 | alloa
# Processing Record 36 of Set 8 | berezovyy
# Processing Record 37 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 38 of Set 8 | talara
# Processing Record 39 of Set 8 | sault ste. marie
# Processing Record 40 of Set 8 | brookings
# Processing Record 41 of Set 8 | gaalkacyo
# Processing Record 42 of Set 8 | sola
# Processing Record 43 of Set 8 | kruisfontein
# Processing Record 44 of Set 8 | avanigadda
# Processing Record 45 of Set 8 | peterhead
# Processing Record 46 of Set 8 | praya
# Processing Record 47 of Set 8 | tuy hoa
# Processing Record 48 of Set 8 | luhansk
# Processing Record 49 of Set 8 | luganville
# Processing Record 0 of Set 9 | kalpatta
# Processing Record 1 of Set 9 | chabahar
# Processing Record 2 of Set 9 | kayangel
# Processing Record 3 of Set 9 | san matias
# Processing Record 4 of Set 9 | sengkang
# Processing Record 5 of Set 9 | kranuan
# Processing Record 6 of Set 9 | alexandria
# Processing Record 7 of Set 9 | koryazhma
# Processing Record 8 of Set 9 | daultala
# Processing Record 9 of Set 9 | palmer
# Processing Record 10 of Set 9 | preobrazheniye
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | altai
# Processing Record 13 of Set 9 | moapa valley
# Processing Record 14 of Set 9 | sardarapat
# Processing Record 15 of Set 9 | tralee
# Processing Record 16 of Set 9 | makar'yev
# Processing Record 17 of Set 9 | kabalo
# Processing Record 18 of Set 9 | turbat
# Processing Record 19 of Set 9 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 20 of Set 9 | howard springs
# Processing Record 21 of Set 9 | fortuna
# Processing Record 22 of Set 9 | breclav
# Processing Record 23 of Set 9 | dolinsk
# Processing Record 24 of Set 9 | kudahuvadhoo
# Processing Record 25 of Set 9 | la'ie
# Processing Record 26 of Set 9 | ganjam
# Processing Record 27 of Set 9 | horta
# Processing Record 28 of Set 9 | kovalam
# Processing Record 29 of Set 9 | vadso
# Processing Record 30 of Set 9 | dudinka
# Processing Record 31 of Set 9 | egilsstadir
# Processing Record 32 of Set 9 | swakopmund
# Processing Record 33 of Set 9 | revda
# Processing Record 34 of Set 9 | aoulef
# Processing Record 35 of Set 9 | dunay
# Processing Record 36 of Set 9 | eisfeld
# Processing Record 37 of Set 9 | lockhart
# Processing Record 38 of Set 9 | saint-pierre
# Processing Record 39 of Set 9 | breyten
# Processing Record 40 of Set 9 | vila do maio
# Processing Record 41 of Set 9 | hithadhoo
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | lebyazh'ye
# Processing Record 44 of Set 9 | hauterive
# Processing Record 45 of Set 9 | la gi
# Processing Record 46 of Set 9 | prince albert
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | tadotsu
# Processing Record 49 of Set 9 | iwanai
# Processing Record 0 of Set 10 | mexico
# Processing Record 1 of Set 10 | sawakin
# Processing Record 2 of Set 10 | nukunonu
# City not found. Skipping...
# Processing Record 3 of Set 10 | sibolga
# Processing Record 4 of Set 10 | arthur's town
# City not found. Skipping...
# Processing Record 5 of Set 10 | chernyshevsk
# Processing Record 6 of Set 10 | beloyarskiy
# Processing Record 7 of Set 10 | kollum
# Processing Record 8 of Set 10 | akureyri
# Processing Record 9 of Set 10 | leava
# Processing Record 10 of Set 10 | moyynkum
# Processing Record 11 of Set 10 | udachny
# Processing Record 12 of Set 10 | sale
# Processing Record 13 of Set 10 | saudarkrokur
# Processing Record 14 of Set 10 | tiquipaya
# Processing Record 15 of Set 10 | umm as sahik
# Processing Record 16 of Set 10 | bandon
# Processing Record 17 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 18 of Set 10 | ha
# City not found. Skipping...
# Processing Record 19 of Set 10 | castro
# Processing Record 20 of Set 10 | holualoa
# Processing Record 21 of Set 10 | mermoz boabab
# Processing Record 22 of Set 10 | dwarka
# Processing Record 23 of Set 10 | alofi
# Processing Record 24 of Set 10 | mata-utu
# Processing Record 25 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | san ignacio
# Processing Record 27 of Set 10 | kargasok
# Processing Record 28 of Set 10 | hof
# Processing Record 29 of Set 10 | wodonga
# Processing Record 30 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 31 of Set 10 | kalocsa
# Processing Record 32 of Set 10 | kenai
# Processing Record 33 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 34 of Set 10 | vieux-habitants
# Processing Record 35 of Set 10 | neuves-maisons
# Processing Record 36 of Set 10 | shobara
# Processing Record 37 of Set 10 | queenstown
# Processing Record 38 of Set 10 | pyhajarvi
# Processing Record 39 of Set 10 | tofol
# Processing Record 40 of Set 10 | khouribga
# Processing Record 41 of Set 10 | murun-kuren
# Processing Record 42 of Set 10 | kovur
# Processing Record 43 of Set 10 | vila franca do campo
# Processing Record 44 of Set 10 | la trinitaria
# Processing Record 45 of Set 10 | candelaria
# Processing Record 46 of Set 10 | konarka
# Processing Record 47 of Set 10 | bathsheba
# Processing Record 48 of Set 10 | koneurgench
# City not found. Skipping...
# Processing Record 49 of Set 10 | acapulco de juarez
# Processing Record 0 of Set 11 | north bend
# Processing Record 1 of Set 11 | utrik
# Processing Record 2 of Set 11 | kokopo
# Processing Record 3 of Set 11 | zanjan
# Processing Record 4 of Set 11 | anamosa
# Processing Record 5 of Set 11 | vilhena
# Processing Record 6 of Set 11 | codrington
# Processing Record 7 of Set 11 | columbia falls
# Processing Record 8 of Set 11 | imam qasim
# Processing Record 9 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 11 | mil'kovo
# Processing Record 11 of Set 11 | pervomayskiy
# Processing Record 12 of Set 11 | pamandzi
# Processing Record 13 of Set 11 | chelak
# Processing Record 14 of Set 11 | eilenburg
# Processing Record 15 of Set 11 | east london
# Processing Record 16 of Set 11 | iskateley
# Processing Record 17 of Set 11 | tamanrasset
# Processing Record 18 of Set 11 | bor
# Processing Record 19 of Set 11 | constitucion
# Processing Record 20 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 21 of Set 11 | rurrenabaque
# Processing Record 22 of Set 11 | yinchuan
# Processing Record 23 of Set 11 | solleftea
# Processing Record 24 of Set 11 | skowhegan
# Processing Record 25 of Set 11 | madera
# Processing Record 26 of Set 11 | maragogi
# Processing Record 27 of Set 11 | santa cruz
# Processing Record 28 of Set 11 | kavaratti
# Processing Record 29 of Set 11 | rostovka
# Processing Record 30 of Set 11 | puerto ayacucho
# Processing Record 31 of Set 11 | daru
# Processing Record 32 of Set 11 | wamba
# Processing Record 33 of Set 11 | margate
# Processing Record 34 of Set 11 | chulym
# Processing Record 35 of Set 11 | ibotirama
# Processing Record 36 of Set 11 | nago
# Processing Record 37 of Set 11 | balqash
# Processing Record 38 of Set 11 | byron bay
# Processing Record 39 of Set 11 | airuk
# Processing Record 40 of Set 11 | nagar
# Processing Record 41 of Set 11 | waingapu
# Processing Record 42 of Set 11 | mili
# Processing Record 43 of Set 11 | tocopilla
# Processing Record 44 of Set 11 | bocas del toro
# Processing Record 45 of Set 11 | midvagur
# Processing Record 46 of Set 11 | aldan
# Processing Record 47 of Set 11 | kangaba
# Processing Record 48 of Set 11 | abra pampa
# Processing Record 49 of Set 11 | hachinohe
# Processing Record 0 of Set 12 | copiapo
# Processing Record 1 of Set 12 | masasi
# Processing Record 2 of Set 12 | trakai
# Processing Record 3 of Set 12 | izki
# Processing Record 4 of Set 12 | palmas
# Processing Record 5 of Set 12 | irituia
# Processing Record 6 of Set 12 | hazorasp
# Processing Record 7 of Set 12 | juan griego
# Processing Record 8 of Set 12 | puerto madero
# Processing Record 9 of Set 12 | dom pedrito
# Processing Record 10 of Set 12 | bogale
# Processing Record 11 of Set 12 | sinabang
# Processing Record 12 of Set 12 | vorkuta
# Processing Record 13 of Set 12 | pasuquin
# Processing Record 14 of Set 12 | santa maria
# Processing Record 15 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 12 | anna regina
# Processing Record 17 of Set 12 | saratamata
# City not found. Skipping...
# Processing Record 18 of Set 12 | ciudad melchor muzquiz
# Processing Record 19 of Set 12 | ewo
# Processing Record 20 of Set 12 | nagato
# Processing Record 21 of Set 12 | northgate
# Processing Record 22 of Set 12 | marina di andora
# City not found. Skipping...
# Processing Record 23 of Set 12 | neiafu
# Processing Record 24 of Set 12 | cill airne
# Processing Record 25 of Set 12 | lamarque
# Processing Record 26 of Set 12 | sohagpur
# Processing Record 27 of Set 12 | dakhla
# Processing Record 28 of Set 12 | santiago del torno
# Processing Record 29 of Set 12 | robore
# Processing Record 30 of Set 12 | kulia village
# City not found. Skipping...
# Processing Record 31 of Set 12 | arkhangel'sk
# Processing Record 32 of Set 12 | nuuk
# Processing Record 33 of Set 12 | rusera
# Processing Record 34 of Set 12 | kill devil hills
# Processing Record 35 of Set 12 | santa rosa de rio primero
# Processing Record 36 of Set 12 | tan-tan
# Processing Record 37 of Set 12 | srivardhan
# Processing Record 38 of Set 12 | tommot
# Processing Record 39 of Set 12 | basco
# Processing Record 40 of Set 12 | dengzhou
# Processing Record 41 of Set 12 | aswan
# Processing Record 42 of Set 12 | mount pearl
# Processing Record 43 of Set 12 | adrar
# Processing Record 44 of Set 12 | maintirano
# Processing Record 45 of Set 12 | ilha solteira
# Processing Record 46 of Set 12 | praia da vitoria
# Processing Record 47 of Set 12 | bengkulu
# Processing Record 48 of Set 12 | naryn
# Processing Record 49 of Set 12 | mao
# Processing Record 0 of Set 13 | valparaiso
# Processing Record 1 of Set 13 | zeya
# Processing Record 2 of Set 13 | glendive
# Processing Record 3 of Set 13 | along
# Processing Record 4 of Set 13 | linqiong
# Processing Record 5 of Set 13 | barra de santo antonio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lon           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lon  Max Temp  Humidity  \
# 0                  yellowknife  62.4560 -114.3525      8.29        71
# 1                    grytviken -54.2811  -36.5092     -3.04        84
# 2  edinburgh of the seven seas -37.0676  -12.3116     15.00        91
# 3            port-aux-francais -49.3500   70.2167      6.24        88
# 4               chernyshevskiy  63.0128  112.4714     17.89        28
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.09      CA  1686629192
# 1          96        4.46      GS  1686629192
# 2         100        8.24      SH  1686629193
# 3         100       13.96      TF  1686629193
# 4           4        0.38      RU  1686629193

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lon  Max Temp  Humidity  \
# City_ID
# 0                        yellowknife  62.4560 -114.3525      8.29        71
# 1                          grytviken -54.2811  -36.5092     -3.04        84
# 2        edinburgh of the seven seas -37.0676  -12.3116     15.00        91
# 3                  port-aux-francais -49.3500   70.2167      6.24        88
# 4                     chernyshevskiy  63.0128  112.4714     17.89        28
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.09      CA  1686629192
# 1                96        4.46      GS  1686629192
# 2               100        8.24      SH  1686629193
# 3               100       13.96      TF  1686629193
# 4                 4        0.38      RU  1686629193

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# needed fields for plots from data frame 
lat = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
current_date= dt.datetime.today().strftime("%y-%m-%d")

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lat, max_temps,
edgecolor="black", linewidth=1, marker="o",
alpha= 0.8, label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature({current_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humbidity
plt.scatter(lat, humidity,
edgecolor="black", linewidth=1, marker="o",
alpha= 0.8, label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity({current_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Humidity")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lat, cloudiness,
edgecolor="black", linewidth=1, marker="o",
alpha= 0.8, label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Cloudiness({current_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lat, wind_speed,
edgecolor="black", linewidth=1, marker="o",
alpha= 0.8, label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity({current_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Wind Speed")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
#%whos.head

# %%
# ignore this code - this was for me to figure out Linear Regression 
# Planning to Define a function to create Linear Regression plots
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Max Temp"].astype("float")

def run_linear_reg(x_values, y_values)
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#create function
plt.scatter(x_values, y_values,
edgecolor="black", linewidth=1, marker="o",
alpha= 0.8, label= "Cities")
plt.plot(x_values,regress_values,color = "r")
plt.annotate(line_eq,(-50,280),color = "r")
# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature({current_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig5.png")

# Show plot
plt.show()
# Out:
#   Cell In[19], line 6
#     def run_linear_reg(x_values, y_values)
#                                           ^
# SyntaxError: expected ':'

# %%
#defining the linear regression
def create_linear_regression(x_values, y_values, title, y_label, annotate_location):
  slope, intercept, r, p, se = linregress(x_values, y_values)
  regress_y = slope * x_values + intercept
  regress_annotation = f"y = {slope:.4f}x + {intercept:.4f}"

  plt.scatter(x_values, y_values, c="b")
  plt.plot(x_values, regress_y, c="r")
  plt.annotate(regress_annotation, annotate_location, c="r", fontsize=15)
  plt.title(title)
  plt.xlabel("Latitude")
  plt.ylabel(y_label)
  plt.grid(True)
  print(f"The p value is {p:.4f} and the r value is {r:.4f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0] 
# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lon  Max Temp  Humidity  \
# City_ID
# 0                     yellowknife  62.4560 -114.3525      8.29        71
# 4                  chernyshevskiy  63.0128  112.4714     17.89        28
# 9                        klaksvik  62.2266   -6.5890      6.51        69
# 10                    luckeesarai  25.1833   86.0833     39.26        31
# 11       petropavlovsk-kamchatsky  53.0452  158.6483     23.33        29
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.09      CA  1686629192
# 4                 4        0.38      RU  1686629193
# 9                95        0.97      FO  1686629194
# 10               18        1.08      IN  1686629194
# 11                0        6.00      RU  1686629194

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lon  Max Temp  Humidity  \
# City_ID
# 1                          grytviken -54.2811 -36.5092     -3.04        84
# 2        edinburgh of the seven seas -37.0676 -12.3116     15.00        91
# 3                  port-aux-francais -49.3500  70.2167      6.24        88
# 5                             pangoa -12.1167 -73.0000     19.49       100
# 6                              pisco -13.7000 -76.2167     17.79        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                96        4.46      GS  1686629192
# 2               100        8.24      SH  1686629193
# 3               100       13.96      TF  1686629193
# 5                53        0.80      PE  1686629193
# 6                 2        2.06      PE  1686629193

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
create_linear_regression(
    x_values = northern_hemi_df["Lat"],
    y_values = northern_hemi_df["Max Temp"],
    title = f"Max Temperature v Latitude ({current_date})",
    y_label = "Max Temperature (C)",
    annotate_location = (8, 8)
)
plt.savefig("output_data/NTvsL_lr.png")

# Show plot
#plt.show()
# Out:
# The p value is 0.0000 and the r value is -0.7774

# %%
# Linear regression on Southern Hemisphere
create_linear_regression(
    x_values = southern_hemi_df["Lat"],
    y_values = southern_hemi_df["Max Temp"],
    title = f"Max Temperature v Latitude ({current_date})",
    y_label = "Max Temperature (C)",
    annotate_location = (-50, 0)
)
plt.savefig("output_data/STvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.0000 and the r value is 0.7584

# %% [markdown]
# **Discussion about the linear relationship:** IN the northern hemisphere as the latitute increased the max temperature decreases. However in the southern hemisphere thre is a postive correlation. As the latitute increases the tempterature increase. IN conclusion as you get closer to the equator (0) the max them increases and as you move farther away the temperature decrease.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(
    x_values = northern_hemi_df["Lat"],
    y_values = northern_hemi_df["Humidity"],
    title = f"Max Temperature v Humidity ({current_date})",
    y_label = "Max Humidity",
    annotate_location = (8, 8)
)
plt.savefig("output_data/NHvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.0337 and the r value is -0.1057

# %%
# Southern Hemisphere
create_linear_regression(
    x_values = southern_hemi_df["Lat"],
    y_values = southern_hemi_df["Humidity"],
    title = f"Max Temperature v Humidity ({current_date})",
    y_label = "Max Humidity",
    annotate_location = (-52, 20)
)
plt.savefig("output_data/SHvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.0442 and the r value is 0.1564

# %% [markdown]
# **Discussion about the linear relationship: The correlation isn't that strong but as latitute increase in the northern hemisphere the humdity decreases and as latiture increases in the southern hemisphere the humidity increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(
    x_values = northern_hemi_df["Lat"],
    y_values = northern_hemi_df["Cloudiness"],
    title = f"Cloudiness v Latitude ({current_date})",
    y_label = "Cloudines",
    annotate_location = (10, 2)
)
plt.savefig("output_data/NCvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.6549 and the r value is 0.0223

# %%
# Southern Hemisphere
create_linear_regression(
    x_values = southern_hemi_df["Lat"],
    y_values = southern_hemi_df["Cloudiness"],
    title = f"Cloudiness v Latitude ({current_date})",
    y_label = "Cloudines",
    annotate_location = (-52, 6)
)
plt.savefig("output_data/SCvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.6648 and the r value is -0.0339

# %% [markdown]
# **Discussion about the linear relationship:** The r value is really close to 0 so there is very weak or no correlation between latiture and cloudiness for both hemispheres

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(
    x_values = northern_hemi_df["Lat"],
    y_values = northern_hemi_df["Wind Speed"],
    title = f"Wind Speed v Latitude ({current_date})",
    y_label = "Wind Speed",
    annotate_location = (10, 2)
)
plt.savefig("output_data/NWvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.7599 and the r value is -0.0152

# %%
# Southern Hemisphere
create_linear_regression(
    x_values = southern_hemi_df["Lat"],
    y_values = southern_hemi_df["Wind Speed"],
    title = f"Wind Speed v Latitude ({current_date})",
    y_label = "Wind Speed",
    annotate_location = (-52, 2)
)
plt.savefig("output_data/SWvsL_lr.png")

# Show plot
plt.show()
# Out:
# The p value is 0.0316 and the r value is -0.1669

# %% [markdown]
# **Discussion about the linear relationship:** The r value is really close to zero. IF you want postive correlation it needs to be close to 1 and for negative close to -1. We can say there is little to no correlation between wind speed and latitude.

# %% [markdown]
# Discussion
